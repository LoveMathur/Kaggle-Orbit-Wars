# %%
from kaggle_environments import make
import json

# 1. Initialize the Orbit Wars environment
env = make("orbit-wars", debug=True)

# 2. Import your local agents
import main as agent1
import basic_agent as agent2

# 3. Run a full simulation match (Agent 1 vs Agent 2)
steps = env.run([agent1.simple_attacker, agent2.simple_attacker])

# 4. See who won!
print("Match finished!")
print(f"Final Rewards/Scores: {env.state[0].reward} vs {env.state[1].reward}")
